# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = {
    'Category': [],
    'Metric': [],
    'Binary_AllFeatures': [],
    'MultiClass_AllFeatures': [],
    'Binary_ExcludingPerplexity': [],
    'MultiClass_ExcludingPerplexity': [],
    'Binary_PerplexityOnly': [],
    'MultiClass_PerplexityOnly': []
}

# Hypothetical Scenarios
data['Category'].extend(['Hypothetical Scenarios'] * 5)
data['Metric'].extend(['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1-score'])
data['Binary_AllFeatures'].extend([0.9646, 0.9656, 0.964, 0.9918, 0.9777])
data['MultiClass_AllFeatures'].extend([0.8617, 0.8692, 0.8655, 0.8692, 0.8633])
data['Binary_ExcludingPerplexity'].extend([0.9453, 0.9403, 0.9484, 0.9835, 0.9657])
data['MultiClass_ExcludingPerplexity'].extend([0.8135, 0.8233, 0.8221, 0.8233, 0.8143])
data['Binary_PerplexityOnly'].extend([0.8971, 0.8676, 0.9137, 0.9588, 0.9357])
data['MultiClass_PerplexityOnly'].extend([0.4341, 0.4395, 0.4449, 0.4395, 0.4275])

# Personal Experience and Storytelling
data['Category'].extend(['Personal Experience and Storytelling'] * 5)
data['Metric'].extend(['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1-score'])
data['Binary_AllFeatures'].extend([0.9767, 0.9707, 0.9798, 0.9921, 0.9859])
data['MultiClass_AllFeatures'].extend([0.8316, 0.8287, 0.8307, 0.8287, 0.8293])
data['Binary_ExcludingPerplexity'].extend([0.9609, 0.9471, 0.9677, 0.9853, 0.9764])
data['MultiClass_ExcludingPerplexity'].extend([0.7795, 0.7773, 0.7864, 0.7773, 0.7788])
data['Binary_PerplexityOnly'].extend([0.88, 0.8042, 0.9133, 0.9433, 0.9281])
data['MultiClass_PerplexityOnly'].extend([0.4744, 0.4717, 0.5086, 0.4717, 0.4702])

# Social and Interpersonal Relationships
data['Category'].extend(['Social and Interpersonal Relationships'] * 5)
data['Metric'].extend(['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1-score'])
data['Binary_AllFeatures'].extend([0.979, 0.9842, 0.9757, 0.9982, 0.9868])
data['MultiClass_AllFeatures'].extend([0.8641, 0.867, 0.8667, 0.867, 0.8659])
data['Binary_ExcludingPerplexity'].extend([0.9608, 0.9588, 0.962, 0.9893, 0.9755])
data['MultiClass_ExcludingPerplexity'].extend([0.8333, 0.8356, 0.8366, 0.8356, 0.8347])
data['Binary_PerplexityOnly'].extend([0.8711, 0.8205, 0.8971, 0.9449, 0.9204])
data['MultiClass_PerplexityOnly'].extend([0.4734, 0.4811, 0.4691, 0.4811, 0.459])

# Practical Advice and Self-Improvement
data['Category'].extend(['Practical Advice and Self-Improvement'] * 5)
data['Metric'].extend(['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1-score'])
data['Binary_AllFeatures'].extend([0.9856, 0.984, 0.9864, 0.9961, 0.9912])
data['MultiClass_AllFeatures'].extend([0.883, 0.8877, 0.8861, 0.8877, 0.8844])
data['Binary_ExcludingPerplexity'].extend([0.9696, 0.9625, 0.9731, 0.9902, 0.9816])
data['MultiClass_ExcludingPerplexity'].extend([0.8446, 0.847, 0.8546, 0.847, 0.8478])
data['Binary_PerplexityOnly'].extend([0.8958, 0.84, 0.9192, 0.9569, 0.9377])
data['MultiClass_PerplexityOnly'].extend([0.4712, 0.4819, 0.4937, 0.4819, 0.4635])

# Philosophical Concepts
data['Category'].extend(['Philosophical Concepts'] * 5)
data['Metric'].extend(['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1-score'])
data['Binary_AllFeatures'].extend([0.9753, 0.9746, 0.9756, 0.995, 0.9852])
data['MultiClass_AllFeatures'].extend([0.9095, 0.9075, 0.9073, 0.9075, 0.9065])
data['Binary_ExcludingPerplexity'].extend([0.9465, 0.9241, 0.9563, 0.9801, 0.9681])
data['MultiClass_ExcludingPerplexity'].extend([0.856, 0.8554, 0.8567, 0.8554, 0.8551])
data['Binary_PerplexityOnly'].extend([0.9218, 0.9109, 0.9252, 0.9851, 0.9542])
data['MultiClass_PerplexityOnly'].extend([0.5226, 0.5065, 0.5259, 0.5065, 0.4984])

df = pd.DataFrame(data)


df_all_features = df[['Category', 'Metric', 'Binary_AllFeatures', 'MultiClass_AllFeatures']]
df_melted = df_all_features.melt(id_vars=['Category', 'Metric'],
                                 var_name='Classification_Type',
                                 value_name='Score')


df_melted['Classification_Type'] = df_melted['Classification_Type'].replace({
    'Binary_AllFeatures': 'Binary',
    'MultiClass_AllFeatures': 'Multi-class'
})


plt.style.use('seaborn-v0_8-whitegrid') 
sns.set_context("paper", font_scale=1.4)

# 추가적인 rcParams 설정으로 세밀한 조정
plt.rcParams.update({
    'font.family': 'serif', 
    'font.serif': ['Times New Roman', 'DejaVu Serif', 'Computer Modern Roman'], 
    'axes.labelsize': 12,
    'axes.titlesize': 14,
    'legend.fontsize': 10,
    'xtick.labelsize': 9,
    'ytick.labelsize': 8, 
    'grid.color': 'lightgray', 
    'grid.linestyle': '--', 
    'grid.linewidth': 0.5, 
    'axes.edgecolor': 'black', 
    'axes.linewidth': 0.8, 
    'patch.edgecolor': 'black', 
    'patch.linewidth': 0.5, 
})

fig1, ax1 = plt.subplots(figsize=(12, 5))
sns.barplot(data=df_melted[df_melted['Classification_Type'] == 'Binary'],
            x='Metric',
            y='Score',
            hue='Category',
            palette=sns.color_palette("Dark2", n_colors=len(df['Category'].unique())),
            edgecolor='black', 
            errorbar=None, 
            ax=ax1)

ax1.set_xlabel('Binary Classification Performance Metric')
ax1.set_ylabel('Score')
ax1.set_ylim(0.7, 1.01) 
ax1.set_yticks([0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0]) 


ax1.tick_params(axis='x')
plt.setp(ax1.get_xticklabels(), rotation=0, ha='center') 

ax1.yaxis.grid(True, linestyle='--', alpha=0.7)
ax1.xaxis.grid(False) # X축 그리드 제거
sns.despine(ax=ax1, top=True, right=True, left=False, bottom=False) 


ax1.legend(title='Category', bbox_to_anchor=(1.02, 1), loc='upper left', frameon=True) 
plt.tight_layout(rect=[0, 0, 0.85, 1]) 
plt.savefig("binary_all_features_performance.png", bbox_inches='tight', dpi = 300)
plt.show()


fig2, ax2 = plt.subplots(figsize=(12, 5))
sns.barplot(data=df_melted[df_melted['Classification_Type'] == 'Multi-class'],
            x='Metric',
            y='Score',
            hue='Category',
            palette=sns.color_palette("Dark2", n_colors=len(df['Category'].unique())),
            edgecolor='black',
            errorbar=None,
            ax=ax2)

ax2.set_xlabel('Multi-class Classification Performance Metric')
ax2.set_ylabel('Score')
ax2.set_ylim(0.3, 0.9) 
ax2.set_yticks([0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9])

ax2.tick_params(axis='x') 
plt.setp(ax2.get_xticklabels(), rotation=0, ha='center')


ax2.yaxis.grid(True, linestyle='--', alpha=0.7)
ax2.xaxis.grid(False)
sns.despine(ax=ax2, top=True, right=True, left=False, bottom=False)


ax2.legend(title='Category', bbox_to_anchor=(1.02, 1), loc='upper left', frameon=True)
plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.savefig("multiclass_all_features_performance.png", bbox_inches='tight', dpi = 300)
plt.show()
